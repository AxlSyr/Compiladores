# %% [markdown]
# <a href="https://colab.research.google.com/github/AxlSyr/Compiladores/blob/main/Examen_Parcial_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1><center>Universidad Autónoma del Estado de Morelos</center></h1>
#
# <h2><center>Instituto de Investigación en Ciencias Básicas y Aplicadas (IICBA)</center></h2>
# <h2><center>Centro de Investigación en Ciencias (CINC)</center></h2>
#
# <h3><center>Curso: Compiladores</center>
# <center>Profesor: Mauricio Rosales Rivera</center>
# <center>Examen Parcial 1</center></h3>
#
# <h3><center>Fecha: Octubre 21, 2020</center></h3>
#
# ---
#
# <h3>Calificación: </h3>
#
# ---
# <h4><center>Estudiante</center></h4>
# <h4>Nombre: Axel Reyes Flores</h4>
# <h4>Matrícula: 10018747</h4>

# %% [markdown]
# Indicaciones: El examen consta de preguntas y ejercicios, las cuales abordan los temas vistos en los Bloques 1 a 3.
#
# En la parte teórica, se evaluará la correcta descripción de los términos.
#
# Fecha de liberación del examen: Miércoles 21 de octubre.
# Fecha límite de entrega: Miércoles 28 de octubre (antes de clase)
#
# Esta notebook deberá contener el nombre completo y matrícula.
#
# En caso de no tener la información aquí solicitada, no se evaluará el examen.

# %% [markdown]
# ## Definiciones Básicas (Introducción):

# %% [markdown]
# ### 1.- ¿Qué es un compilador y un interprete?

# %% [markdown]
# Un compilador es un programa que traduce un programa escrito en un lenguaje de programación de alto nivel que es adecuado para programadores humanos al lenguaje de máquina de bajo nivel que requieren las computadoras. Durante este proceso, el compilador también intentará detectar e informar errores obvios del programador.
#
# Un intérprete es un programa que toma el árbol de sintaxis abstracta de un programa
# y lo ejecuta inspeccionando el árbol de sintaxis para ver qué se necesita hacer. Esto es
# similar a cómo un humano evalúa una expresión matemática: insertamos los valores
# de variables en la expresión y evaluarla poco a poco, comenzando con la más interna
# paréntesis y saliendo hasta que tengamos el resultado de la expresión. Luego podemos repetir el proceso con otros valores para las variables.

# %% [markdown]
# ### 2.- ¿Cuál es la diferencia entre ellos?

# %% [markdown]
# Un intérprete es otra forma de implementar un lenguaje de programación. La interpretación comparte muchos aspectos con la compilación. La lectura, el análisis sintáctico y la verificación de tipos se realizan en un intérprete como en un compilador. Pero en lugar de generar código a partir del árbol de sintaxis, el árbol de sintaxis se procesa directamente para evaluar expresiones y
# ejecutar sentencias, etc. Es posible que un intérprete deba procesar la misma pieza
# del árbol de sintaxis (por ejemplo, el cuerpo de un bucle) muchas veces y, por lo tanto, la interpretación suele ser más lenta que la ejecución de un programa compilado. Pero escribir un intérprete es a menudo más simple que escribir un compilador y el intérprete es más fácil de mover a una máquina diferente, por lo que para aplicaciones donde la velocidad no es esencial, a menudo se utilizan intérpretes.

# %% [markdown]
# ### 3.- ¿Qué es un lenguaje de programación?

# %% [markdown]
# Un lenguaje de programación es un lenguaje formal que comprende un conjunto de instrucciones que producen varios tipos de resultados. Los lenguajes de programación se utilizan en la programación de computadoras para implementar algoritmos.

# %% [markdown]
# ### 4.- Proporciona un esquema de las fases que comprenden a un compilador

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 5.- ¿Cuáles son las operaciones que llevan a cabo los compiladores e interpretes?

# %% [markdown]
# Llevan acabo un análisis léxico del programa a traducir o ejecutar, un análisis sintáctico y un análisis semántico del mismo.

# %% [markdown]
# ### 6.- Proporciona al menos 3 tipos de lenguajes de programación y da ejemplos de cada uno de ellos:
#
# * El cuerpo deberá tener un ciclo de 10 incrementos y que imprima lo que contiene un valor i

# %% [markdown]
# Python
#
# ```
# for i in range(10):
#   print(i)
# ```

# %% [markdown]
# C
# ```
# for (int i = 0; i < 10; i++) {
#     printf("%")
# }
# ```

# %% [markdown]
# Java
#
#
#
# ```
# for (int i = 0; i < 10;  i++) {
#     System.out.println(i);
# }
# ```

# %% [markdown]
# ## Definiciones Básicas (Scanner):

# %% [markdown]
# ### 1.- ¿Qué es un analizador léxico?

# %% [markdown]
# El escáner, o analizador léxico, lee un flujo de caracteres y
# produce un torrente de palabras.
#
# Dado que los escáneres realizan una tarea relativamente sencilla, agrupar
# caracteres juntos para formar palabras y puntuación en la fuente
# lenguaje, se prestan a implementaciones rápidas.

# %% [markdown]
# ### 2.- ¿Cuál es la función de un Scanner?

# %% [markdown]
# Un scanner tomará como entrada una cadena de letras individuales y dividirá esta cadena en tokens. Además, filtrará lo que separe los tokens (los llamados espacios en blanco), es decir, los caracteres de diseño (espacios, nuevas líneas, etc.) y los comentarios.
#
# La tarea del escáner es transformar un flujo de caracteres en un
# flujo de palabras en el idioma de entrada. Cada palabra debe ser
# clasificado en una categoría sintáctica o "parte del discurso".
#
# Un scanner debe cumplir con las siguientes funciones:
#
# 1. Encontrar tokens
# 2. Instalar un nuevo identificador en la tabla de símbolos y devolver la dirección
# 3. Devolver la dirección de la tabla de símbolos de un identificador previamente instalado
# 4. Producir una lista numerada del programa fuente.
# 5. Generar mensajes de error para errores léxicos.

# %% [markdown]
# ### 3.- ¿Qué es un autómata y qué elementos los componen?

# %% [markdown]
# Definición formal de un Autómata Finito (Determinista)
# Un autómata finito es una 5-ada $(Q, \Sigma, \delta, q_0, F)$
#
# 1. $Q$ es un conjunto finito llamado conjunto de estados.
# 2. $\Sigma$ es un conjunto finito llamado alfabeto.
# 3. $\delta: Q \times \Sigma \to Q$ es la función de transición.
# 4. $q_0 \in Q$ es el estado inicial.
# 5. $F \subseteq Q$ es el conjunto de estados de aceptación.
#
# Un autómata finito A = (I, O, S, f, g, σ) es una máquina de estado finito en la que el conjunto de símbolos de salida es {0, 1} y donde el estado actual determina la última salida. Los estados para los que la última salida fue 1 se denominan estados de aceptación.
#
# En un sentido abstracto, es una máquina que tiene un número finito de estados y un número finito de transiciones entre ellos. Una transición entre estados generalmente se etiqueta con un carácter del alfabeto de entrada, pero también usaremos transiciones marcadas con ε, las llamadas transiciones épsilon. Se puede utilizar un autómata finito para decidir si una cadena de entrada es un miembro de algún conjunto particular de cadenas. Para hacer esto, seleccionamos uno de los estados del autómata como estado inicial.

# %% [markdown]
# ### 4.- ¿Qué es una expresión Regular?

# %% [markdown]
# Dado un alfabeto, describiremos conjuntos de cadenas mediante expresiones regulares, una notación algebraica que es compacta y fácil de usar y comprender para los humanos. La idea es que las expresiones regulares que describen conjuntos simples de cadenas se pueden combinar para formar expresiones regulares que describen conjuntos de cadenas más complejos.
#
# Decimos que $R$ es una expresión regular si es
#
# 1. $a$ para algún $a\in \sigma$
# 2. $\epsilon$
# 3. $\emptyset$
# 4. $R_1 \cup R_2$ donde $R_1$ y $R_2$ son expresiones regulares
# 5. $R_1 \circ R_2$ donde $R_1$ y $R_2$ son expresiones regulares
# 6. $R_1^{\star}$ donde $R_1$ es una expresión regular

# %% [markdown]
# ### 5.- Proporciona el esquema para la construcción de:
# * RE -> NFA -> DFA -> RE

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Definiciones Básicas (Parser):

# %% [markdown]
# ### 1.-¿Qué es una Parser?

# %% [markdown]
# Es la fase del analizador que se encarga de revisar el texto de entrada en base a una gramática dada. Y en caso de que el programa de entrada sea válido, suministra el árbol sintáctico que lo reconoce.
#
# En teoría, se supone que la salida del analizador sintáctico es alguna representación del árbol sintáctico que reconoce la secuencia de tokens
# suministrada por el analizador léxico.

# %% [markdown]
# ### 2.- ¿Qué operaciones realiza el analizador sintáctico?

# %% [markdown]
# 1. Acceder a la tabla de símbolos (para hacer parte del trabajo del analizador semántico).
# 2. Revisión de tipos (del analizador semántico).
# 3. Generar código intermedio.
# 4. Generar errores cuando se producen.

# %% [markdown]
# ### 3.- Explica la relación que existe entre un Scanner y un Parser

# %% [markdown]
# Un parser toma como entrada la salida de un analizador léxico en la forma de streams de tokens. El parser compara el código fuente (stream de tokens) contra las reglas de producción de la gramática para detectar cualquier error en el código. La salida de un
# analizador sintáctico es entonces un árbol de parseo.

# %% [markdown]
# ### 4.- ¿Cómo se lleva a cabo la comunicación entre ellos? Proporciona un diagrama y explicalo

# %% [markdown]
# Un analizador sintáctico o parser toma como entrada la salida de un analizador léxico en la forma de streams de tokens. El parser compara el
# código fuente (stream de tokens) contra las reglas de producción de la
# gramática para detectar cualquier error en el código. La salida de un
# analizador sintáctico es entonces un árbol de parseo.

# %% [markdown]
# ![relation.png](data:image/png;base64,...)

# %% [markdown]
# Un analizador léxico no puede revisar la sintaxis para una sentencia dadas las limitaciones que las expresiones regulares presentan.
# Las expresiones regulares no pueden revisar el balanceo de tokens, como
# paréntesis, llaves y corchetes, entonces esta fase utiliza una gramática
# libre de contexto la cual es reconocida por un automata "push-down".

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# El analizador léxico tiene que dividir la secuencia de caracteres en
# palabras con significado propio y después convertirlo a una secuencia de
# terminales desde el punto de vista delanalizador sintáctico, que es la entrada del analizador sintáctico.
#
# El analizador léxico reconoce las palabras en función de una gramática regular de manera que sus NO TERMINALES se convierten en los elementos de entrada de fases posteriores.

# %% [markdown]
# ### 5.- ¿Qué es una Gramática Libre de Contexto y qué elementos lo componen?

# %% [markdown]
# La gramática que acepta el analizador sintáctico es una gramática libre de contexto:
#
# Gramática: G = (N, T, P, S)
# 1. N = No terminales.
# 2. T = Terminales.
# 3. P = Reglas de Producción.
# 4. S = Axioma Inicial.

# %% [markdown]
# ### 6.-¿Cuáles son las Gramáticas tipo LL y LR? Proporciona un ejemplo de ambas y, además, menciona la diferencia entre ellas.

# %% [markdown]
# **LL**
#
# El análisis descendente se basa en la gramática LL, que permite analizar una frase de entrada sin que exista bloqueos mutuos.
#
# * Primera L: Significa que la entrada será leída de izquierda a derecha (left).
# * Segunda L: Indica derivaciones por la izquierda (left).
# * Numero 1 : Indica que se lee por anticipado un símbolo en
# cualquier proceso de análisis sintáctico (usa un símbolo de preanalisis)
#
# Una leftmost derivation se obtiene aplicando la producción a la variable más a la izquierda en cada paso.

# %% [markdown]
# Una derivación LL para una cadena a + a * a puede ser
#
# X → X + X → a + X → a + X * X → a + a * X → a + a * a

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **LR**
#
# También conocidos como Parser LR, utilizan la técnica de análisis por desplazamiento reducción.
#
# * L: Significa que la entrada será leída de izquierda a derecha (left).
# * R: Indica derivaciones por la derecha (right).
# * k : Indica lectura por anticipado de "k" símbolos (k símbolos de preanálisis).
#
# Una rightmost derivation se obtiene aplicando la producción a la variable más a la derecha en cada paso.

# %% [markdown]
# Una derivación LR para una cadena a + a * a puede ser
#
# X → X * X → X * a → X + X * a → X + a * a → a + a * a

# %% [markdown]
# ![image.png](data:image/png;base64,...)
